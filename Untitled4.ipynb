# %% [markdown]
# <a href="https://colab.research.google.com/github/PANKAJ-GUPTA-201998/Time-Series-Forcasting-By-ARIMA-Holt-Winters-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pmdarima

# %%
# Import Libraries
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pylab import rcParams
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
# Import data from and in DataFram
data = pd.read_csv('/content/ACTUAL_DATASET (1).csv')
del data['MEMORY']
data.columns = ['Time','Request']
data['Time'] = pd.to_datetime(data['Time'], format='%d.%m.%Y %H:%M:%S')
Time = data.pop('Time')
data.head()
# Out:
#    Request
# 0      307
# 1      223
# 2      134
# 3      116
# 4      134

# %%
#ADF to chek the series Stationarity
from statsmodels.tsa.stattools import adfuller
adf_test = adfuller(data)

print('ADF Statistic: %f' % adf_test[0])
print('No of Lags: %f' % adf_test[2])
print('No of Observations: %f' % adf_test[3])
print('Critical Values @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistic: -6.203997
# No of Lags: 17.000000
# No of Observations: 1998.000000
# Critical Values @ 0.05: -2.86
# p-value: 0.000000

# %%
result = seasonal_decompose(data, model='multiplicative', period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
# Convert data on Log to reduce the magnitude of the values and reduce the rising trend in the series 
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(data)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
# Check the corrct values and model
model_autoARIMA1 = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find             optimal 'd'
                      max_p=4, max_q=4, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10820.879, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8498.413, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-2225.684, Time=0.29 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-2240.483, Time=0.87 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-2289.002, Time=1.77 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=-2285.933, Time=1.84 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-2309.384, Time=1.37 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-2274.223, Time=1.98 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=-2333.776, Time=5.08 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=-2231.752, Time=5.82 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-2226.305, Time=6.84 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-2331.976, Time=9.31 sec
#
# Best model:  ARIMA(4,0,2)(0,0,0)[0]
# Total fit time: 35.919 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1811
# Model:               SARIMAX(4, 0, 2)   Log Likelihood                1173.888
# Date:                Thu, 21 Apr 2022   AIC                          -2333.776
# Time:                        16:10:23   BIC                          -2295.264
# Sample:                             0   HQIC                         -2319.564
#                                - 1811
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2308      0.014     16.656      0.000       0.204       0.258
# ar.L2          1.1430      0.013     84.677      0.000       1.117       1.170
# ar.L3         -0.2284      0.013    -17.101      0.000      -0.255      -0.202
# ar.L4         -0.1455      0.013    -10.982      0.000      -0.171      -0.119
# ma.L1          0.0372      0.008      4.662      0.000       0.022       0.053
# ma.L2         -0.9348      0.006   -159.649      0.000      -0.946      -0.923
# sigma2         0.0159   8.95e-05    177.879      0.000       0.016       0.016
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):            632454.47
# Prob(Q):                              0.70   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.54   Skew:                             6.80
# Prob(H) (two-sided):                  0.00   Kurtosis:                        93.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Residual Data plot
model_autoARIMA1.plot_diagnostics(figsize=(15,8))
plt.show()

# %%
import statsmodels.api as sm

# %%
# Fit the data on ARMA modeal with parameter (3,3)
model = sm.tsa.arima.ARIMA(train_data, order=(4, 0, 2))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                Request   No. Observations:                 1811
# Model:                 ARIMA(4, 0, 2)   Log Likelihood                1188.166
# Date:                Thu, 21 Apr 2022   AIC                          -2360.333
# Time:                        16:10:31   BIC                          -2316.320
# Sample:                             0   HQIC                         -2344.091
#                                - 1811
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7958      0.022    215.800      0.000       4.752       4.839
# ar.L1          0.1324      0.030      4.384      0.000       0.073       0.192
# ar.L2          1.0679      0.024     44.177      0.000       1.021       1.115
# ar.L3         -0.1631      0.022     -7.491      0.000      -0.206      -0.120
# ar.L4         -0.1015      0.016     -6.242      0.000      -0.133      -0.070
# ma.L1          0.1194      0.027      4.495      0.000       0.067       0.171
# ma.L2         -0.8559      0.027    -32.275      0.000      -0.908      -0.804
# sigma2         0.0157      0.000    121.054      0.000       0.015       0.016
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            654434.66
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.54   Skew:                             7.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        95.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# ljungbox test
import statsmodels.api as sm
sm.stats.acorr_ljungbox(fitted.resid, lags=[20], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 20  53.010232   0.000081

# %%
fc = fitted.forecast(274, alpha=0.05) 
print(fc) # 95% confidence
fc_series = pd.Series(fc, index=test_data.index, name="Request")
plt.plot(train_data, label='Training')
plt.plot(test_data, color = 'blue', label='Actual')
plt.plot(fc_series, color = 'orange',label='Predicted')
plt.title('CPU Data Prediction (Train/Test/Predict)')
plt.legend(loc='upper right', fontsize=8)
plt.show()
# Out:
# 1814    4.817309
# 1815    4.857777
# 1816    4.819400
# 1817    4.851998
# 1818    4.816146
#           ...
# 2083    4.807472
# 2084    4.784059
# 2085    4.807439
# 2086    4.784092
# 2087    4.807407
# Name: predicted_mean, Length: 274, dtype: float64

# %%
# report performance after train and test
p = fc_series.to_frame()
fc = fc[:202]
mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(test_data['Request']- p['Request']/np.abs(test_data['Request'])))
print('MAPE: '+str(mape))
mpe = np.mean((test_data['Request']- p['Request']/np.abs(test_data['Request'])*100))
print('MPE: '+str(mpe))
me = np.mean(test_data['Request']- p['Request'])
print('ME: '+str(me))
# Out:
# MSE: 0.026138473179884422
# MAE: 0.09714347101857197
# RMSE: 0.16167397186895738
# MAPE: 3.847303129082643
# MPE: -94.44247501197809
# ME: 0.03945397069067931

# %%
# Now final pridict for 7 another days and now used all data set to train the model
model_pr = sm.tsa.arima.ARIMA(df_log, order=(4, 0, 3))  
fitted_pr = model_pr.fit()  
print(fitted_pr.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                Request   No. Observations:                 2016
# Model:                 ARIMA(4, 0, 3)   Log Likelihood                1297.885
# Date:                Thu, 21 Apr 2022   AIC                          -2577.771
# Time:                        16:10:41   BIC                          -2527.291
# Sample:                             0   HQIC                         -2559.243
#                                - 2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.8133      0.026    184.595      0.000       4.762       4.864
# ar.L1          0.5213      0.147      3.554      0.000       0.234       0.809
# ar.L2          1.0251      0.035     29.219      0.000       0.956       1.094
# ar.L3         -0.5231      0.140     -3.730      0.000      -0.798      -0.248
# ar.L4         -0.0421      0.036     -1.172      0.241      -0.112       0.028
# ma.L1         -0.2354      0.147     -1.597      0.110      -0.524       0.054
# ma.L2         -0.9262      0.021    -45.022      0.000      -0.967      -0.886
# ma.L3          0.2669      0.122      2.189      0.029       0.028       0.506
# sigma2         0.0162      0.000    116.483      0.000       0.016       0.017
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):            544708.87
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.68   Skew:                             6.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        82.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast for 7 another days so 2,016 records required
x = pd.Series(range(test_data.index.max()+1,4752))
fc_pr = fitted_pr.forecast(2016, alpha=0.05)  # 95% confidence
fc_series_pr = pd.Series(fc_pr, index = x, name="Request")
plt.plot(df_log, label='Actual')
plt.plot(fc_series_pr, color = 'green',label='Predicted')
plt.title('CPU Data Prediction')
plt.legend(loc='upper right', fontsize=10)
plt.show()

# %%
# Creating final pridict data set and recover the original series
pridict_data_CPU = np.round((np.exp(fc_series_pr)),0)
pridict_data_CPU.head()
# Out:
# 2016    154.0
# 2017    149.0
# 2018    149.0
# 2019    147.0
# 2020    147.0
# Name: Request, dtype: float64

# %%
# Plot the actualy (Recovered) series with actual
plt.figure(figsize=(7,3), dpi=100)
plt.plot(data, label='Actual')
plt.plot(pridict_data_CPU, color = 'green',label='Predicted')
plt.legend(loc='upper right', fontsize=10)
plt.show()

# %%
# Export data in 'pridict_data_CPU.csv' 
pridict_data_CPU.to_csv(r'C:\Users\Pankaj\Downloads\New Project\pridict_data_CPU.csv', index = False)
